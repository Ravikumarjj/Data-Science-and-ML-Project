# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

data = pd.read_csv("demand.csv")
data.head()
# Out:
#    ID  Store ID  Total Price  Base Price  Units Sold
# 0   1      8091      99.0375    111.8625          20
# 1   2      8091      99.0375     99.0375          28
# 2   3      8091     133.9500    133.9500          19
# 3   4      8091     133.9500    133.9500          44
# 4   5      8091     141.0750    141.0750          52

# %%
data.isnull().sum()
# Out:
# ID             0
# Store ID       0
# Total Price    1
# Base Price     0
# Units Sold     0
# dtype: int64

# %%
data = data.dropna()

# %%
fig = px.scatter(data, x="Units Sold", y="Total Price", size = "Units Sold")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\KIIT\OneDrive\Desktop\Data Science  & ML Project\PRODUCT DEMAND PREDICTION\product-demand-prediction.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/KIIT/OneDrive/Desktop/Data%20Science%20%20%26%20ML%20Project/PRODUCT%20DEMAND%20PREDICTION/product-demand-prediction.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> fig = px.scatter(data, x="Units Sold", y="Total Price", size = "Units Sold")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KIIT/OneDrive/Desktop/Data%20Science%20%20%26%20ML%20Project/PRODUCT%20DEMAND%20PREDICTION/product-demand-prediction.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
print(data.corr())
# Out:
#                    ID  Store ID  Total Price  Base Price  Units Sold
# ID           1.000000  0.007461     0.008473    0.018911   -0.010608
# Store ID     0.007461  1.000000    -0.038315   -0.038855   -0.004369
# Total Price  0.008473 -0.038315     1.000000    0.958885   -0.235625
# Base Price   0.018911 -0.038855     0.958885    1.000000   -0.140022
# Units Sold  -0.010608 -0.004369    -0.235625   -0.140022    1.000000

# %%
correlations = data.corr(method='pearson')
plt.figure(figsize=(15, 12))
sns.heatmap(correlations, cmap="coolwarm", annot=True)
plt.show()

# %%
x = data[["Total Price", "Base Price"]]
y = data["Units Sold"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, 
                                                test_size=0.2, 
                                                random_state=42)
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor()

# %%
#features = [["Total Price", "Base Price"]]
features = np.array([[133.00, 140.00]])
model.predict(features)
# Out:
# C:\Users\KIIT\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning:
#
# X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
# array([27.])
